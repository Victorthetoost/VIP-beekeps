# %%
#visualize the empty hive overlayed with differnet hives
import matplotlib.pyplot as plt
import pandas as pd

#combine Sencor C and sensor E to get the empty hive data
empty_hive = pd.Dataframe()
C = pd.read_csv("Sensor C_export_202512201200.csv")
E = pd.read_csv("Sensor E_export_202512201200.csv")
#Name,Date,Temperature_Fahrenheit,Relative_Humidity,Temperature_Farenheit_Edge,Relative_Humidity_Edge,Temperature_Farenheit_Difference_C-E,
#Relative_Humidity_C-E,Alive_or_Dead,Difference In Temperature From Empty Center,
#Difference In Temperature From Empty Edge,Difference In Humidity From Empty Center,Difference In Humidity From Empty Edge
empty_hive["name"] = "Empty Hive"
empty_hive["Timestamp"] = C["Timestamp for sample frequency every 15 min"]
empty_hive["Temperature_Fahrenheit"] = C["Temperature_Fahrenheit"]
empty_hive["Relative_Humidity"] = C["Relative_Humidity"]
